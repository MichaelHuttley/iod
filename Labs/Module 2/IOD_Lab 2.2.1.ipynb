# %% [markdown]
# <div>
# <img src=https://www.institutedata.com/wp-content/uploads/2019/10/iod_h_tp_primary_c.svg width="300">
# </div>

# %% [markdown]
# # Lab 2.2.1

# %% [markdown]
# # Data
#
# > The sinking of the RMS Titanic is one of the most infamous shipwrecks in history.  On April 15, 1912, during her maiden voyage, the Titanic sank after colliding with an iceberg, killing 1502 out of 2224 passengers and crew. This sensational tragedy shocked the international community and led to better safety regulations for ships.
#
# > One of the reasons that the shipwreck led to such loss of life was that there were not enough lifeboats for the passengers and crew. Although there was some element of luck involved in surviving the sinking, some groups of people were more likely to survive than others, such as women, children, and the upper-class.
#
# In this lab, we'll explore this dataset to find insight.
#
# [Titanic Dataset](https://www.kaggle.com/c/titanic/data)

# %% [markdown]
# # Data Dictionary
#
# | Variable |                                 Definition | Key                                            |
# |----------|-------------------------------------------:|------------------------------------------------|
# | Survival | Survival                                   | 0 = No, 1 = Yes                                |
# | Pclass   | Ticket class                               | 1 = 1st, 2 = 2nd, 3 = 3rd                      |
# | Sex      | Sex                                        |                                                |
# | Age      | Age in years                               |                                                |
# | SibSp    | # of siblings / spouses aboard the Titanic |                                                |
# | Parch    | # of parents / children aboard the Titanic |                                                |
# | Ticket   | Ticket number                              |                                                |
# | Fare     | Passenger fare                             |                                                |
# | Cabin    | Cabin number                               |                                                |
# | Embarked | Port of Embarkation                        | C = Cherbourg, Q = Queenstown, S = Southampton |

# %% [markdown]
# # Loading Modules

# %%
# Load necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# # Loading Dataset
#
# Read titanic dataset.

# %%
# Read Titanic Dataset
titanic_csv = 'titanic_train.csv'
titanic = pd.read_csv(titanic_csv)

# %% [markdown]
# # Explore Dataset

# %% [markdown]
# ## Head

# %%
# Check Head
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# ## Tail

# %%
# Check Tail
titanic.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %% [markdown]
# ## Shape
#
# Find shape of dataset.

# %%
# ANSWER
titanic.shape
# Out:
# (891, 12)

# %%
titanic.describe(include = 'all')
# Out:
#         PassengerId    Survived      Pclass                             Name  \
# count    891.000000  891.000000  891.000000                              891
# unique          NaN         NaN         NaN                              891
# top             NaN         NaN         NaN  Nilsson, Miss. Helmina Josefina
# freq            NaN         NaN         NaN                                1
# mean     446.000000    0.383838    2.308642                              NaN
# std      257.353842    0.486592    0.836071                              NaN
# min        1.000000    0.000000    1.000000                              NaN
# 25%      223.500000    0.000000    2.000000                              NaN
# 50%      446.000000    0.000000    3.000000                              NaN
# 75%      668.500000    1.000000    3.000000                              NaN
# max      891.000000    1.000000    3.000000                              NaN
#
# ...

# %% [markdown]
# ## Check Types of Data
#
# Check types of data you have

# %%
# ANSWER
titanic.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# ## Check Null Values
#
# Check whether dataset have any null values.

# %%
# ANSWER
titanic.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
# Check titanic data again
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# ## Fill Null Values
#
# Is there any null values in any columns?
#
# - Identify those columns
# - Fill those null values using your own logic
#     - State your logic behind every steps

# %% [markdown]
# ### Age

# %%
#allowing the all data to be displayed
pd.set_option('display.max_rows', None)

# %%
#looking at null values
titanic[titanic['Age'].isnull() == True]
# Out:
#      PassengerId  Survived  Pclass  \
# 5              6         0       3
# 17            18         1       2
# 19            20         1       3
# 26            27         0       3
# 28            29         1       3
# 29            30         0       3
# 31            32         1       1
# 32            33         1       3
# 36            37         1       3
# 42            43         0       3
# 45            46         0       3
# 46            47         0       3
# 47            48         1       3
# 48            49         0       3
# 55            56         1       1
# 64            65         0       1
# 65            66         1       3
# 76            77         0       3
# 77            78         0       3
# 82            83         1       3
# 87            88         0       3
# 95            96         0       3
# 101          102         0       3
# 107          108         1       3
# 109          110         1       3
# ...

# %%
#replacing all null values with the mean age
    #Ideally I would replace the null values with a normal distribution realted to the ages already within the coloum, but i wasn't sure how to do it
    #So instead it was replaced by the average as it seemed to be the second best option
titanic.Age.fillna(titanic.Age.mean(), inplace=True)

# %%
#checking if the function worked by seaching for null values
titanic[titanic['Age'].isnull() == True]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
#checking another way
titanic.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# ### Cabin

# %%
#looking at null values
#display broke so fixing it to a max of data values displayed
pd.set_option('display.max_rows', 10)
titanic[titanic['Cabin'].isnull() == True]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 0              1         0       3                   Braund, Mr. Owen Harris
# 2              3         1       3                    Heikkinen, Miss. Laina
# 4              5         0       3                  Allen, Mr. William Henry
# 5              6         0       3                          Moran, Mr. James
# 7              8         0       3            Palsson, Master. Gosta Leonard
# ..           ...       ...     ...                                       ...
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 890          891         0       3                       Dooley, Mr. Patrick
#
# ...

# %%
#looking at true values to compare them
titanic[titanic['Cabin'].isnull() == False]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#Taken note that it seems that Pclass 3 often don't have cabin, probably due to Pclass 1 having a more expensive ticket
#Upon initial look seems to be true
#checking to see if its true
pclassFareMean = titanic.groupby(['Pclass'])['Fare'].mean()
pclassFareMean
# Out:
# Pclass
# 1    84.154687
# 2    20.662183
# 3    13.675550
# Name: Fare, dtype: float64

# %%
#replacing the null value with a string that implies the null value, while giving further information on why that is the case
titanic.Cabin.fillna(value = 'no cabin', inplace=True)

# %%
#checking it worked
titanic[titanic['Cabin'].isnull() == True]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
#Looking at the data
titanic.Cabin
# Out:
# 0      no cabin
# 1           C85
# 2      no cabin
# 3          C123
# 4      no cabin
#          ...
# 886    no cabin
# 887         B42
# 888    no cabin
# 889        C148
# 890    no cabin
# Name: Cabin, Length: 891, dtype: object

# %%
#noted it's worked

# %% [markdown]
# ### Embarked

# %%
#Looking at the data, setting max display rows again
pd.set_option('display.max_rows', None)
titanic.Embarked
# Out:
# 0        S
# 1        C
# 2        S
# 3        S
# 4        S
# 5        Q
# 6        S
# 7        S
# 8        S
# 9        C
# 10       S
# 11       S
# 12       S
# 13       S
# 14       S
# 15       S
# 16       Q
# 17       S
# 18       S
# 19       C
# 20       S
# 21       S
# 22       Q
# 23       S
# 24       S
# 25       S
# 26       C
# 27       S
# 28       Q
# 29       S
# 30       C
# 31       C
# 32       Q
# 33       S
# 34       C
# 35       S
# 36       C
# 37       S
# 38       S
# 39       C
# 40       S
# 41       S
# 42       C
# 43       C
# 44       Q
# 45       S
# 46       Q
# 47       Q
# 48       C
# 49       S
# 50       S
# 51       S
# 52       C
# 53       S
# 54       C
# 55       S
# 56       S
# 57       C
# 58       S
# 59       S
# 60       C
# 61     NaN
# 62       S
# 63       S
# 64       C
# 65       C
# 66       S
# 67       S
# 68       S
# 69       S
# 70       S
# 71       S
# 72       S
# 73       C
# 74       S
# 75       S
# ...

# %%
#seeing the distribution of the Embarked coloumn
titanic['Embarked'].value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
#As their isn't any information about why there is null values, they have been replaced by an object data type that displays this information
titanic.Embarked.fillna(value = 'Unknown', inplace=True)

# %%
#checking it worked
titanic['Embarked'].value_counts()
# Out:
# S          644
# C          168
# Q           77
# Unknown      2
# Name: Embarked, dtype: int64

# %% [markdown]
# # Describe
#
# Describe your dataset.

# %%
#looks for any more null values
titanic.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
#Notes no more null values

# %%
titanic.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
#Notes that all data-types are correct

# %%
#describing the dataset
titanic.describe(include = 'all')
# Out:
#         PassengerId    Survived      Pclass                             Name  \
# count    891.000000  891.000000  891.000000                              891
# unique          NaN         NaN         NaN                              891
# top             NaN         NaN         NaN  Nilsson, Miss. Helmina Josefina
# freq            NaN         NaN         NaN                                1
# mean     446.000000    0.383838    2.308642                              NaN
# std      257.353842    0.486592    0.836071                              NaN
# min        1.000000    0.000000    1.000000                              NaN
# 25%      223.500000    0.000000    2.000000                              NaN
# 50%      446.000000    0.000000    3.000000                              NaN
# 75%      668.500000    1.000000    3.000000                              NaN
# max      891.000000    1.000000    3.000000                              NaN
#
# ...

# %% [markdown]
# # Relationship between Features and Survival
#
# Find relationship between categorical features and survived.
#
# **Describe your findings.**

# %%
def bar_charts(df, feature):
    '''
    Inputs:
    df: Dataset
    feature: Name of Feature to Check With Survived
    '''
    _agg = {
        'PassengerId': 'count'
    }
    _groupby = ['Survived', feature]

    df_feature = df.groupby(by=_groupby).agg(_agg)
    
    ax = df_feature.unstack().plot(kind='bar', figsize=(15,6))
    plt.legend(list(df_feature.index.levels[1].unique()))
    plt.xlabel('Survived')
    plt.xticks(np.arange(2), ('No', 'Yes'))
    plt.show()

# %% [markdown]
# ## Pclass
#
# Use barchart to find relationship between survived and pclass.  Note your findings.

# %%
titanic['Pclass'].value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
#From information above we can remember that the average ticket price gets lower the higher the Pclass
#We also note that Pclass 3 has the greatest number of people
bar_charts(titanic, 'Pclass')

# %%
#according to this chart the greater the amount of money spent on the ticket the more likely you were to survivie
#With Plcass 1 having the highest number of survived passangers
#Pclass 2 has the lowest but we can note that they also have the lowst number of passangers in that class
#The group with the highest deaths are people from Pclass 3 which supports previous hypothesis
#Pclass 3 did have a higher number of survived citizens than Pclass 2 but it also had also double the amount of people within it
#Note that the Pclass 3 Bar is not twice as tall as Pclass 2

# %% [markdown]
# ## Sex
#
# Use barchart to find relationship between survived and sex.  Note your findings.

# %%
titanic['Sex'].value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
#Note that there are more males than females

# %%
bar_charts(titanic, 'Sex')

# %%
#Looking at the graph it is clear that Felames has a significantly higher rate of survivial

# %% [markdown]
# ## Parch
#
# Parch = Number of parents of children travelling with each passenger.

# %%
#looking at the value counts of parents/children to help understand the graph
titanic['Parch'].value_counts()
#Also 3 ,4, 5 and 6 all have very small sample sizes comparably to 0, 1, 2
# Out:
# 0    678
# 1    118
# 2     80
# 5      5
# 3      5
# 4      4
# 6      1
# Name: Parch, dtype: int64

# %%
#Notes that the number of people with no parents or children completely outnumbers any other group
#Also

# %%
#Looking at the distribution of parents/children survived to help get an understanding of the data
parchSurvived = titanic.groupby(['Parch'])['Survived'].value_counts()
parchSurvived
# Out:
# Parch  Survived
# 0      0           445
#        1           233
# 1      1            65
#        0            53
# 2      0            40
#        1            40
# 3      1             3
#        0             2
# 4      0             4
# 5      0             4
#        1             1
# 6      0             1
# Name: Survived, dtype: int64

# %%
#Noted 0 Parch and Died almost twice outwheigh, 0 Parch and survived
#While

# %%
bar_charts(titanic, 'Parch')

# %%
#Taking all that into account we can see that while most of the people that survived had 0 parents or children with them
#The priority of those who survived we're familys

# %% [markdown]
# ## SibSp

# %%
bar_charts(titanic, 'SibSp')

# %%
titanic['SibSp'].value_counts()
# Out:
# 0    608
# 1    209
# 2     28
# 4     18
# 3     16
# 8      7
# 5      5
# Name: SibSp, dtype: int64

# %%
#Alot of SibSp has a crossover of information with the Parch data, and so this data emphasises that people in familys were given
#priority of Survival

# %% [markdown]
# ## Embarked

# %%
bar_charts(titanic, 'Embarked')

# %%
titanic['Embarked'].value_counts()
# Out:
# S          644
# C          168
# Q           77
# Unknown      2
# Name: Embarked, dtype: int64

# %%
embarkedSurvived = titanic.groupby(['Embarked'])['Survived'].value_counts()
embarkedSurvived
# Out:
# Embarked  Survived
# C         1            93
#           0            75
# Q         0            47
#           1            30
# S         0           427
#           1           217
# Unknown   1             2
# Name: Survived, dtype: int64

# %%
#Notes that everyone who potenially snuck on also survived (odd but due to sample size mostly irrelevent)
#Looking at this information we can deduct that port S had the lowest survival rate

# %% [markdown]
# # Feature Engineering
#
# Create some new features from existing feature.

# %% [markdown]
# ## Fare Class
#
# Create a new class based on their fare. Is there any relationship between fare and survival?

# %%
def create_fare_class(x):
    if x > 30:
        fare_class = 1
    elif x > 20 and x <= 30:
        fare_class = 2
    elif x > 10 and x <= 20:
        fare_class = 3
    else:
        fare_class = 4
    return fare_class

# %%
fare_class_list = []
#titanic['Fare_class'] = 0
for i in range(len(titanic)):
    k = create_fare_class(titanic['Fare'][i])
    fare_class_list.append(k)
    #titanic['Fare_class'].loc[i] = k

titanic['Fare_class'] = fare_class_list

# %%
titanic['Fare_class'] = titanic['Fare'].apply(create_fare_class)

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare     Cabin Embarked  Fare_class
# 0      0         A/5 21171   7.2500  no cabin        S           4
# 1      0          PC 17599  71.2833       C85        C           1
# 2      0  STON/O2. 3101282   7.9250  no cabin        S           4
# ...

# %%
#Note that as Fare_class gets higher, the fare is lower

# %%
bar_charts(titanic, 'Fare_class')

# %%
titanic['Fare_class'].value_counts()
# Out:
# 4    336
# 1    234
# 3    179
# 2    142
# Name: Fare_class, dtype: int64

# %%
#By the appearance of the graph fare_class 1 (the highest payers), were the only people who has a survival rate of above 50%

# %% [markdown]
# ## Age Class

# %%
def create_age_class(x):
    if x > 60:
        age_class = 5
    elif x > 35 and x <= 60:
        age_class = 4
    elif x > 25 and x <= 35:
        age_class = 3
    elif x > 16 and x <= 25:
        age_class = 2
    else:
        age_class = 1
    return age_class

# %%
age_class_list = []
#titanic['Fare_class'] = 0
for i in range(len(titanic)):
    k = create_age_class(titanic['Age'][i])
    age_class_list.append(k)
    #titanic['Fare_class'].loc[i] = k

titanic['Age_class'] = age_class_list

# %%
titanic['Age_class'] = titanic['Age'].apply(create_age_class)

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare     Cabin Embarked  Fare_class  Age_class
# 0      0         A/5 21171   7.2500  no cabin        S           4          2
# 1      0          PC 17599  71.2833       C85        C           1          4
# 2      0  STON/O2. 3101282   7.9250  no cabin        S           4          3
# ...

# %%
titanic['Age_class'].value_counts()
# Out:
# 3    373
# 2    201
# 4    195
# 1    100
# 5     22
# Name: Age_class, dtype: int64

# %%
bar_charts(titanic, 'Age_class')

# %%
#The No graph is slightly positivly skewed, while the yes graph is slightly negativly skewed
#However, the number of survived in group 1 is more than the number of of people who died in group 1
#This is the only age_class where this occurs
#we can deduct that children had priority over adults, but also the older the adult is more likely to survive

# %% [markdown]
# # Statistical Overview

# %% [markdown]
# ## Correlation
#
# Find correlation between `survived` and other features.

# %%
titanic.corr()
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.033207 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481 -0.069809 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000 -0.331339  0.083081  0.018443
# Age             0.033207 -0.069809 -0.331339  1.000000 -0.232625 -0.179191
# SibSp          -0.057527 -0.035322  0.083081 -0.232625  1.000000  0.414838
# Parch          -0.001652  0.081629  0.018443 -0.179191  0.414838  1.000000
# Fare            0.012658  0.257307 -0.549500  0.091566  0.159651  0.216225
# Fare_class      0.003258 -0.307600  0.719670 -0.108947 -0.380692 -0.387100
# Age_class       0.026653 -0.067911 -0.292128  0.933632 -0.232166 -0.168121
#
#                  Fare  Fare_class  Age_class
# PassengerId  0.012658    0.003258   0.026653
# Survived     0.257307   -0.307600  -0.067911
# Pclass      -0.549500    0.719670  -0.292128
# ...

# %%
sys_bp=[183, 152, 178, 157, 194, 163, 144, 114, 178, 152, 118, 158, 172, 138]

mu=165

# %%
from scipy import stats

t_statistic,p_value=stats.ttest_1samp(sys_bp,mu)

# %%
p_value
# Out:
# 0.23575481011813063

# %%
one_tailed_p_value=float("{:.6f}".format(p_value/2)) # Since alternative hypothesis is one tailed, We need to divide the p value by 2.

print('Test statistic is %f'%float("{:.6f}".format(t_statistic)))
print('p-value for one tailed test is %f'%one_tailed_p_value)
# Out:
# Test statistic is -1.243183
# p-value for one tailed test is 0.117877

# %%
sys_bp=[183, 152, 178, 157, 194, 163, 144, 114, 178, 152, 118, 158, 172, 138]

mu=165


from scipy import stats

t_value,p_value=stats.ttest_1samp(sys_bp,mu)

one_tailed_p_value=float("{:.6f}".format(p_value/2)) # Since alternative hypothesis is one tailed, We need to divide the p value by 2.

print('Test statistic is %f'%float("{:.6f}".format(t_value)))
print('p-value for one tailed test is %f'%one_tailed_p_value)

alpha = 0.05
if one_tailed_p_value<=alpha:

    print('Conclusion','n','Since p-value(=%f)'%p_value,'<','alpha(=%.2f)'%alpha,'''We reject the null hypothesis H0. 
    So we conclude that there is a significant mean difference in systolic blood pressure. 
    i.e., μ = 165 at %.2f level of significance'''%alpha)

else:

    print('Conclusion','n','Since p-value(=%f)'%one_tailed_p_value,'>','alpha(=%.2f)'%alpha,'''We do not reject the null hypothesis H0.''')
# Out:
# Test statistic is -1.243183
# p-value for one tailed test is 0.117877
# Conclusion n Since p-value(=0.117877) > alpha(=0.05) We do not reject the null hypothesis H0.

# %%
#statistically significant means the null hypothesis got rejected.

# %% [markdown]
# # [BONUS] Hypothesis Testing
# ---
# The usual process of null hypothesis testing consists of four steps.
#
# 1. Formulate the null hypothesis H_0 (commonly, that the observations are the result of pure chance) and the alternative hypothesis H_a (commonly, that the observations show a real effect combined with a component of chance variation).
#
# 2. Identify a test statistic that can be used to assess the truth of the null hypothesis.
#
# 3. Compute the p-value, which is the probability that a test statistic at least as significant as the one observed would be obtained assuming that the null hypothesis were true. The smaller the p-value, the stronger the evidence against the null hypothesis.
#
# 4. Compare the p-value to an acceptable significance value alpha (sometimes called an alpha value). If p<=alpha, that the observed effect is statistically significant, the null hypothesis is ruled out, and the alternative hypothesis is valid.

# %% [markdown]
# ### Define Hypothesis
#
# > Formulate the null hypothesis H_0 (commonly, that the observations are the result of pure chance) and the alternative hypothesis H_a (commonly, that the observations show a real effect combined with a component of chance variation).
#
#     Null Hypothesis (H0): There is no difference in the survival rate between the young and old passengers.
#
#     Alternative Hypothesis (HA): There is a difference in the survival rate between the young and old passengers.

# %% [markdown]
# ### Collect Data
#
# Next step is to collect data for each population group.
#
# Collect two sets of data, one with the passenger greater than 35 years of age and another one with the passenger younger than 35. The sample size should ideally be the same but it can be different. Lets say that the sample sizes is 100.

# %%
# ANSWER

# %% [markdown]
# ### Set alpha (let alpha = 0.05)
#
# > Identify a test statistic that can be used to assess the truth of the null hypothesis.

# %%
# ANSWER

# %% [markdown]
# ### Calculate point estimate

# %%
a = titanic_young['Survived']
b = titanic_old['Survived']

# %%
## Calculate the variance to get the standard deviation
var_a = a.var(ddof = 1)
var_b = b.var(ddof = 1)

## Calculate the Standard Deviation
s = np.sqrt((var_a + var_b)/2)

# %% [markdown]
# ### Calculate test statistic

# %%
## Calculate the t-statistic
t = (a.mean() - b.mean())/(s*np.sqrt(2/N))

# %% [markdown]
# ### Find the p-value
#
# > Compute the P-value, which is the probability that a test statistic at least as significant as the one observed would be obtained assuming that the null hypothesis were true. The smaller the P-value, the stronger the evidence against the null hypothesis.

# %%
## Compare with the critical t-value
## Degrees of freedom
df = 2*N - 2

#p-value after comparison with the t 
if (t > 0):
    p = 1 - stats.t.cdf(t, df = df) 
else:
    p = stats.t.cdf(t, df = df)

# %%
print("t = " + str(t))
print("p = " + str(2*p))

# %% [markdown]
# ### Interpret results
#
# > Compare the p-value to an acceptable significance value  alpha (sometimes called an alpha value). If p<=alpha, that the observed effect is statistically significant, the null hypothesis is ruled out, and the alternative hypothesis is valid.

# %%
def print_sig(p_value, alpha):
    if p_value < alpha:
        print("We reject our null hypothesis.")
    elif p_value > alpha:
        print("We fail to reject our null hypothesis.")
    else:
        print("Our test is inconclusive.")

# %%
## Cross Checking with the internal scipy function
t2, p2 = stats.ttest_ind(a,b)
print("t = " + str(t2))
print("p = " + str(p2))

print_sig(p2, alpha)

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# > > > > > > > > > © 2022 Institute of Data
#
#
# ---
#
#
#
# ---
